# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
_fp = "C:\development\phinix-nexus-v1\src\outputs\pipeline_pipeline_visualizer_output_2024-07-08_1720467284.csv"
df = pd.read_csv(_fp)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\sandh\AppData\Local\Temp\ipykernel_27504\1300302007.py:4: SyntaxWarning: invalid escape sequence '\d'
#   _fp = "C:\development\phinix-nexus-v1\src\outputs\pipeline_pipeline_visualizer_output_2024-07-08_1720467284.csv"

# %%
df.head()
# Out:
#   ELEXXXXX_id   ELEXXXXX_name PARXXXXX_id     PARXXXXX_name  ELE_x  ELE_y  \
# 0    ELE00001  Typical Debris    PAR00001              Mass    240    760
# 1    ELE00001  Typical Debris    PAR00002  Angular velocity    240    760
# 2    ELE00001  Typical Debris    PAR00002  Angular velocity    240    760
# 3    ELE00001  Typical Debris    PAR00003  Orbital altitude    240    760
# 4    ELE00001  Typical Debris    PAR00003  Orbital altitude    240    760
#
#    ELE_height  PAR_y  PAR_width             fields  ... fill_color  \
# 0         151     26        220         mechanical  ...    #3399FF
# 1         151     51        220         mechanical  ...    #3399FF
# 2         151     51        220         mechanical  ...    #3399FF
# 3         151     76        220  orbital_mechanics  ...    #60A917
# 4         151     76        220      mision_design  ...    #60A917
#
#   line_XXXXX_id target_PARXXXXX_id value_iftext value_ifnominal  \
# 0           NaN                NaN          NaN             NaN
# 1           NaN                NaN          NaN             NaN
# 2           NaN                NaN          NaN             NaN
# 3           NaN                NaN          NaN             NaN
# 4           NaN                NaN          NaN             NaN
#
#   value_ifrange_min value_ifrange_max  value_units  value_margin_percentage  \
# 0              25.0             144.0           kg                      NaN
# 1               0.1              30.0        deg/s                      NaN
# 2               0.1              30.0        deg/s                      NaN
# 3             500.0            1000.0           km                      NaN
# 4             500.0            1000.0           km                      NaN
#
#                                     description
# 0                                           NaN
# 1  speed of rotation of the uncontrolled debris
# 2  speed of rotation of the uncontrolled debris
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 23 columns]

# %%
import base64
import io, requests
from IPython.display import Image, display
from pillow import Image as im
import matplotlib.pyplot as plt
